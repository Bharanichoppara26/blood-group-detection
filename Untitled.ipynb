# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Subset
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from featureExtractor import Features  # Your pip package

# --------------------- Configuration --------------------- #
BATCH_SIZE = 32  # Increased for stability
EPOCHS = 50
NUM_CLASSES = 8
LR = 1e-5  # Reduced learning rate
IMAGE_SIZE = 128
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# --------------------- Dataset & Stratified Split --------------------- #
transform = transforms.Compose([
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

dataset = datasets.ImageFolder(root="./dataset", transform=transform)
labels = [label for _, label in dataset.samples]

splitter = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=42)
train_idx, temp_idx = next(splitter.split(np.zeros(len(labels)), labels))
temp_labels = [labels[i] for i in temp_idx]

splitter2 = StratifiedShuffleSplit(n_splits=1, test_size=0.5, random_state=42)
val_idx, test_idx = next(splitter2.split(np.zeros(len(temp_labels)), temp_labels))
val_idx = [temp_idx[i] for i in val_idx]
test_idx = [temp_idx[i] for i in test_idx]

train_ds = Subset(dataset, train_idx)
val_ds = Subset(dataset, val_idx)
test_ds = Subset(dataset, test_idx)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers = os.cpu_count())
val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE, num_workers = os.cpu_count())
test_loader = DataLoader(test_ds, batch_size=BATCH_SIZE, num_workers = os.cpu_count())

# --------------------- Model Definition --------------------- #
class Classifier(nn.Module):
    def __init__(self, num_classes=8):
        super().__init__()
        self.feature_extractor = Features()
        self.pool = nn.AdaptiveAvgPool2d(1)
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, num_classes)
        )

    def forward(self, x):
        x = self.feature_extractor(x)
        x = self.pool(x)
        return self.classifier(x)

model = Classifier(num_classes=NUM_CLASSES).to(DEVICE)
criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=LR)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=2, verbose=True)

# Freeze extractor initially
for param in model.feature_extractor.parameters():
    param.requires_grad = False

train_loss_history, val_loss_history = [], []
train_acc_history, val_acc_history = [], []
best_val_acc = 0.0

# --------------------- Training --------------------- #
def train():
    global best_val_acc
    for epoch in range(EPOCHS):
        if epoch == 5:
            print(">>> 🔓 Unfreezing feature extractor")
            for param in model.feature_extractor.parameters():
                param.requires_grad = True

        model.train()
        total_loss, correct = 0, 0
        for images, labels in train_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=2.0)
            optimizer.step()

            total_loss += loss.item() * images.size(0)
            correct += (outputs.argmax(1) == labels).sum().item()

        train_loss = total_loss / len(train_ds)
        train_acc = correct / len(train_ds)
        val_loss, val_acc = evaluate(val_loader, split="Validation", record=False)

        train_loss_history.append(train_loss)
        train_acc_history.append(train_acc)
        val_loss_history.append(val_loss)
        val_acc_history.append(val_acc)

        scheduler.step(val_acc)

        if val_acc > best_val_acc:
            best_val_acc = val_acc
            torch.save(model.state_dict(), "best_model1.pth")
            print(f"✅ Best model saved (epoch {epoch+1}) | Val Acc: {val_acc:.4f}")

        print(f"[Epoch {epoch+1}] LR: {optimizer.param_groups[0]['lr']:.6f} | "
              f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.4f} | "
              f"Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f}")

# --------------------- Evaluation --------------------- #
def evaluate(loader, split="Test", record=True):
    model.eval()
    all_preds, all_labels, all_probs = [], [], []

    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = model(images)
            probs = torch.softmax(outputs, dim=1)
            preds = torch.argmax(probs, dim=1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            all_probs.extend(probs.cpu().numpy())

    labels_np = np.array(all_labels)
    probs_np = np.array(all_probs)
    preds_np = np.array(all_preds)

    if record:
        print(f"\n[Classification Report - {split} Set]")
        print(classification_report(labels_np, preds_np, digits=4))

        cm = confusion_matrix(labels_np, preds_np)
        plt.figure(figsize=(10, 8))
        sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=dataset.classes, yticklabels=dataset.classes)
        plt.title(f"{split} Confusion Matrix")
        plt.xlabel("Predicted")
        plt.ylabel("True")
        plt.tight_layout()
        plt.show()

        # ROC Curve
        labels_bin = label_binarize(labels_np, classes=list(range(NUM_CLASSES)))
        fpr, tpr, roc_auc = {}, {}, {}
        for i in range(NUM_CLASSES):
            fpr[i], tpr[i], _ = roc_curve(labels_bin[:, i], probs_np[:, i])
            roc_auc[i] = auc(fpr[i], tpr[i])

        plt.figure(figsize=(10, 8))
        for i in range(NUM_CLASSES):
            plt.plot(fpr[i], tpr[i], label=f"Class {i} (AUC={roc_auc[i]:.2f})")
        plt.plot([0, 1], [0, 1], 'k--')
        plt.title(f"{split} ROC Curve")
        plt.xlabel("False Positive Rate")
        plt.ylabel("True Positive Rate")
        plt.legend(loc="lower right")
        plt.tight_layout()
        plt.show()

    loss = criterion(torch.tensor(probs_np), torch.tensor(labels_np).long())
    acc = np.mean(preds_np == labels_np)
    return loss.item(), acc

# --------------------- Metrics Plot --------------------- #
def plot_metrics():
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(train_loss_history, label="Train Loss")
    plt.plot(val_loss_history, label="Val Loss")
    plt.title("Loss per Epoch")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(train_acc_history, label="Train Acc")
    plt.plot(val_acc_history, label="Val Acc")
    plt.title("Accuracy per Epoch")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()

    plt.tight_layout()
    plt.show()

# --------------------- Main --------------------- #
if __name__ == "__main__":
    train()
    evaluate(test_loader, split="Test")
    plot_metrics()
# Out:
# /home/jupyter-228w1a4216/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# ✅ Best model saved (epoch 1) | Val Acc: 0.1189
# [Epoch 1] LR: 0.000010 | Train Loss: 2.0961 | Train Acc: 0.1329 | Val Loss: 2.0779 | Val Acc: 0.1189
# ✅ Best model saved (epoch 2) | Val Acc: 0.1511
# [Epoch 2] LR: 0.000010 | Train Loss: 2.0884 | Train Acc: 0.1314 | Val Loss: 2.0771 | Val Acc: 0.1511
# ✅ Best model saved (epoch 3) | Val Acc: 0.1733
# [Epoch 3] LR: 0.000010 | Train Loss: 2.0773 | Train Acc: 0.1571 | Val Loss: 2.0764 | Val Acc: 0.1733
# [Epoch 4] LR: 0.000010 | Train Loss: 2.0708 | Train Acc: 0.1555 | Val Loss: 2.0759 | Val Acc: 0.1689
# [Epoch 5] LR: 0.000010 | Train Loss: 2.0685 | Train Acc: 0.1624 | Val Loss: 2.0755 | Val Acc: 0.1678
# >>> 🔓 Unfreezing feature extractor
# ✅ Best model saved (epoch 6) | Val Acc: 0.2278
# [Epoch 6] LR: 0.000010 | Train Loss: 2.0322 | Train Acc: 0.1869 | Val Loss: 2.0647 | Val Acc: 0.2278
# ✅ Best model saved (epoch 7) | Val Acc: 0.2933
# [Epoch 7] LR: 0.000010 | Train Loss: 1.9505 | Train Acc: 0.2474 | Val Loss: 2.0483 | Val Acc: 0.2933
# ✅ Best model saved (epoch 8) | Val Acc: 0.3456
# [Epoch 8] LR: 0.000010 | Train Loss: 1.8586 | Train Acc: 0.3076 | Val Loss: 2.0319 | Val Acc: 0.3456
# ✅ Best model saved (epoch 9) | Val Acc: 0.4544
# [Epoch 9] LR: 0.000010 | Train Loss: 1.7847 | Train Acc: 0.3543 | Val Loss: 2.0181 | Val Acc: 0.4544
# [Epoch 10] LR: 0.000010 | Train Loss: 1.7225 | Train Acc: 0.3821 | Val Loss: 2.0067 | Val Acc: 0.4211
# ✅ Best model saved (epoch 11) | Val Acc: 0.5000
# [Epoch 11] LR: 0.000010 | Train Loss: 1.6660 | Train Acc: 0.4012 | Val Loss: 1.9908 | Val Acc: 0.5000
# ✅ Best model saved (epoch 12) | Val Acc: 0.5167
# [Epoch 12] LR: 0.000010 | Train Loss: 1.6150 | Train Acc: 0.4336 | Val Loss: 1.9791 | Val Acc: 0.5167
# ✅ Best model saved (epoch 13) | Val Acc: 0.5322
# [Epoch 13] LR: 0.000010 | Train Loss: 1.5577 | Train Acc: 0.4626 | Val Loss: 1.9654 | Val Acc: 0.5322
# ✅ Best model saved (epoch 14) | Val Acc: 0.5722
# [Epoch 14] LR: 0.000010 | Train Loss: 1.5214 | Train Acc: 0.4750 | Val Loss: 1.9548 | Val Acc: 0.5722
# [Epoch 15] LR: 0.000010 | Train Loss: 1.4919 | Train Acc: 0.4807 | Val Loss: 1.9510 | Val Acc: 0.5422
# [Epoch 16] LR: 0.000010 | Train Loss: 1.4613 | Train Acc: 0.4938 | Val Loss: 1.9383 | Val Acc: 0.5644
# ✅ Best model saved (epoch 17) | Val Acc: 0.5922
# [Epoch 17] LR: 0.000010 | Train Loss: 1.4203 | Train Acc: 0.5076 | Val Loss: 1.9250 | Val Acc: 0.5922
# [Epoch 18] LR: 0.000010 | Train Loss: 1.3964 | Train Acc: 0.5202 | Val Loss: 1.9236 | Val Acc: 0.5922
# ✅ Best model saved (epoch 19) | Val Acc: 0.6133
# [Epoch 19] LR: 0.000010 | Train Loss: 1.3706 | Train Acc: 0.5312 | Val Loss: 1.9165 | Val Acc: 0.6133
# ✅ Best model saved (epoch 20) | Val Acc: 0.6344
# [Epoch 20] LR: 0.000010 | Train Loss: 1.3484 | Train Acc: 0.5326 | Val Loss: 1.9038 | Val Acc: 0.6344
# ✅ Best model saved (epoch 21) | Val Acc: 0.6589
# [Epoch 21] LR: 0.000010 | Train Loss: 1.3364 | Train Acc: 0.5329 | Val Loss: 1.8924 | Val Acc: 0.6589
# [Epoch 22] LR: 0.000010 | Train Loss: 1.3118 | Train Acc: 0.5512 | Val Loss: 1.8885 | Val Acc: 0.6389
# [Epoch 23] LR: 0.000010 | Train Loss: 1.2939 | Train Acc: 0.5455 | Val Loss: 1.8921 | Val Acc: 0.6100
# [Epoch 24] LR: 0.000005 | Train Loss: 1.2626 | Train Acc: 0.5662 | Val Loss: 1.8775 | Val Acc: 0.6556
# ✅ Best model saved (epoch 25) | Val Acc: 0.6767
# [Epoch 25] LR: 0.000005 | Train Loss: 1.2601 | Train Acc: 0.5605 | Val Loss: 1.8766 | Val Acc: 0.6767
# [Epoch 26] LR: 0.000005 | Train Loss: 1.2407 | Train Acc: 0.5743 | Val Loss: 1.8756 | Val Acc: 0.6367
# [Epoch 27] LR: 0.000005 | Train Loss: 1.2279 | Train Acc: 0.5812 | Val Loss: 1.8766 | Val Acc: 0.6356
# [Epoch 28] LR: 0.000003 | Train Loss: 1.2307 | Train Acc: 0.5767 | Val Loss: 1.8667 | Val Acc: 0.6522
# [Epoch 29] LR: 0.000003 | Train Loss: 1.2199 | Train Acc: 0.5926 | Val Loss: 1.8634 | Val Acc: 0.6744
# [Epoch 30] LR: 0.000003 | Train Loss: 1.2131 | Train Acc: 0.5821 | Val Loss: 1.8632 | Val Acc: 0.6733
# [Epoch 31] LR: 0.000001 | Train Loss: 1.2025 | Train Acc: 0.5864 | Val Loss: 1.8585 | Val Acc: 0.6678
# ✅ Best model saved (epoch 32) | Val Acc: 0.6856
# [Epoch 32] LR: 0.000001 | Train Loss: 1.2023 | Train Acc: 0.5962 | Val Loss: 1.8575 | Val Acc: 0.6856
# [Epoch 33] LR: 0.000001 | Train Loss: 1.2039 | Train Acc: 0.5921 | Val Loss: 1.8560 | Val Acc: 0.6789
# [Epoch 34] LR: 0.000001 | Train Loss: 1.1991 | Train Acc: 0.5945 | Val Loss: 1.8552 | Val Acc: 0.6856
# [Epoch 35] LR: 0.000001 | Train Loss: 1.1960 | Train Acc: 0.5898 | Val Loss: 1.8564 | Val Acc: 0.6700
# [Epoch 36] LR: 0.000001 | Train Loss: 1.1854 | Train Acc: 0.5957 | Val Loss: 1.8538 | Val Acc: 0.6822
# [Epoch 37] LR: 0.000001 | Train Loss: 1.1971 | Train Acc: 0.5893 | Val Loss: 1.8543 | Val Acc: 0.6822
# [Epoch 38] LR: 0.000000 | Train Loss: 1.1972 | Train Acc: 0.5938 | Val Loss: 1.8539 | Val Acc: 0.6822
# [Epoch 39] LR: 0.000000 | Train Loss: 1.1900 | Train Acc: 0.5948 | Val Loss: 1.8559 | Val Acc: 0.6722
# [Epoch 40] LR: 0.000000 | Train Loss: 1.1934 | Train Acc: 0.5840 | Val Loss: 1.8545 | Val Acc: 0.6822
# ✅ Best model saved (epoch 41) | Val Acc: 0.6878
# [Epoch 41] LR: 0.000000 | Train Loss: 1.1964 | Train Acc: 0.5814 | Val Loss: 1.8504 | Val Acc: 0.6878
# [Epoch 42] LR: 0.000000 | Train Loss: 1.1911 | Train Acc: 0.5890 | Val Loss: 1.8551 | Val Acc: 0.6711
# [Epoch 43] LR: 0.000000 | Train Loss: 1.1904 | Train Acc: 0.5955 | Val Loss: 1.8513 | Val Acc: 0.6733
# [Epoch 44] LR: 0.000000 | Train Loss: 1.1781 | Train Acc: 0.6083 | Val Loss: 1.8525 | Val Acc: 0.6733
# [Epoch 45] LR: 0.000000 | Train Loss: 1.1823 | Train Acc: 0.6026 | Val Loss: 1.8546 | Val Acc: 0.6767
# [Epoch 46] LR: 0.000000 | Train Loss: 1.1889 | Train Acc: 0.5895 | Val Loss: 1.8526 | Val Acc: 0.6844
# ✅ Best model saved (epoch 47) | Val Acc: 0.6978
# [Epoch 47] LR: 0.000000 | Train Loss: 1.1828 | Train Acc: 0.5998 | Val Loss: 1.8547 | Val Acc: 0.6978
# [Epoch 48] LR: 0.000000 | Train Loss: 1.1809 | Train Acc: 0.6019 | Val Loss: 1.8532 | Val Acc: 0.6878
# [Epoch 49] LR: 0.000000 | Train Loss: 1.1767 | Train Acc: 0.6010 | Val Loss: 1.8532 | Val Acc: 0.6967
# [Epoch 50] LR: 0.000000 | Train Loss: 1.1877 | Train Acc: 0.5819 | Val Loss: 1.8547 | Val Acc: 0.6967
#
# [Classification Report - Test Set]
#               precision    recall  f1-score   support
#
#            0     0.8333    0.7647    0.7975        85
#            1     0.6154    0.6842    0.6480       152
#            2     0.6034    0.6604    0.6306       106
#            3     0.6238    0.5526    0.5860       114
#            4     0.7222    0.6633    0.6915        98
#            5     0.7752    0.9009    0.8333       111
#            6     0.7206    0.7656    0.7424       128
#            7     0.4268    0.3271    0.3704       107
#
#     accuracy                         0.6659       901
#    macro avg     0.6651    0.6649    0.6625       901
# weighted avg     0.6595    0.6659    0.6602       901

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader, Subset
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# --------------------- Configuration --------------------- #
BATCH_SIZE = 32
EPOCHS = 100
NUM_CLASSES = 8
LR_CLASSIFIER = 1e-3  # Higher LR for classifier
LR_FEATURE_EXTRACTOR = 1e-5  # Lower LR for feature extractor
IMAGE_SIZE = 128
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# --------------------- Transforms with Data Augmentation --------------------- #
transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

transform_val_test = transforms.Compose([
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# --------------------- Dataset & Stratified Split --------------------- #
dataset = datasets.ImageFolder(root="./dataset")  # Load without transform initially

labels = [label for _, label in dataset.samples]

splitter = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=42)
train_idx, temp_idx = next(splitter.split(np.zeros(len(labels)), labels))
temp_labels = [labels[i] for i in temp_idx]

splitter2 = StratifiedShuffleSplit(n_splits=1, test_size=0.5, random_state=42)
val_idx, test_idx = next(splitter2.split(np.zeros(len(temp_labels)), temp_labels))
val_idx = [temp_idx[i] for i in val_idx]
test_idx = [temp_idx[i] for i in test_idx]

# Custom dataset class to apply different transforms
class TransformedSubset(torch.utils.data.Dataset):
    def __init__(self, subset, transform=None):
        self.subset = subset
        self.transform = transform

    def __getitem__(self, index):
        x, y = self.subset[index]
        if self.transform:
            x = self.transform(x)
        return x, y

    def __len__(self):
        return len(self.subset)

train_ds = TransformedSubset(Subset(dataset, train_idx), transform=transform_train)
val_ds = TransformedSubset(Subset(dataset, val_idx), transform=transform_val_test)
test_ds = TransformedSubset(Subset(dataset, test_idx), transform=transform_val_test)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=os.cpu_count())
val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE, num_workers=os.cpu_count())
test_loader = DataLoader(test_ds, batch_size=BATCH_SIZE, num_workers=os.cpu_count())

# --------------------- Model Definition --------------------- #
class Classifier(nn.Module):
    def __init__(self, num_classes=8):
        super().__init__()
        resnet = models.resnet18(pretrained=True)
        self.feature_extractor = nn.Sequential(*list(resnet.children())[:-2])  # Remove FC and avgpool
        self.pool = nn.AdaptiveAvgPool2d(1)
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.BatchNorm1d(256),
            nn.Dropout(0.5),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.BatchNorm1d(128),
            nn.Dropout(0.5),
            nn.Linear(128, num_classes)
        )

    def forward(self, x):
        x = self.feature_extractor(x)
        x = self.pool(x)
        return self.classifier(x)

model = Classifier(num_classes=NUM_CLASSES).to(DEVICE)

# Freeze feature extractor initially
for param in model.feature_extractor.parameters():
    param.requires_grad = False

criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.classifier.parameters(), lr=LR_CLASSIFIER)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=3, verbose=True)

train_loss_history, val_loss_history = [], []
train_acc_history, val_acc_history = [], []
best_val_acc = 0.0

# --------------------- Training --------------------- #
def train():
    global best_val_acc
    for epoch in range(EPOCHS):
        if epoch == 5:  # Unfreeze earlier to allow fine-tuning
            print(">>> 🔓 Unfreezing feature extractor")
            for param in model.feature_extractor.parameters():
                param.requires_grad = True
            optimizer.add_param_group({'params': model.feature_extractor.parameters(), 'lr': LR_FEATURE_EXTRACTOR})

        model.train()
        total_loss, correct = 0, 0
        for images, labels in train_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=2.0)
            optimizer.step()

            total_loss += loss.item() * images.size(0)
            correct += (outputs.argmax(1) == labels).sum().item()

        train_loss = total_loss / len(train_ds)
        train_acc = correct / len(train_ds)
        val_loss, val_acc = evaluate(val_loader, split="Validation", record=False)

        train_loss_history.append(train_loss)
        train_acc_history.append(train_acc)
        val_loss_history.append(val_loss)
        val_acc_history.append(val_acc)

        scheduler.step(val_acc)

        if val_acc > best_val_acc:
            best_val_acc = val_acc
            torch.save(model.state_dict(), "best_model.pth")
            print(f"✅ Best model saved (epoch {epoch+1}) | Val Acc: {val_acc:.4f}")

        current_lr = optimizer.param_groups[0]['lr']  # Display LR of classifier
        print(f"[Epoch {epoch+1}] LR: {current_lr:.6f} | "
              f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.4f} | "
              f"Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f}")

# --------------------- Evaluation --------------------- #
def evaluate(loader, split="Test", record=True):
    model.eval()
    total_loss = 0
    all_preds, all_labels, all_probs = [], [], []

    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = model(images)
            loss = criterion(outputs, labels)  # Use logits directly
            total_loss += loss.item() * images.size(0)
            probs = torch.softmax(outputs, dim=1)
            preds = torch.argmax(probs, dim=1)

            all_preds.append(preds.cpu())
            all_labels.append(labels.cpu())
            all_probs.append(probs.cpu())

    avg_loss = total_loss / len(loader.dataset)
    labels_np = torch.cat(all_labels).numpy()
    preds_np = torch.cat(all_preds).numpy()
    probs_np = torch.cat(all_probs).numpy()
    acc = np.mean(preds_np == labels_np)

    if record:
        print(f"\n[{split} Set]")
        print(f"Loss: {avg_loss:.4f} | Accuracy: {acc:.4f}")
        print(classification_report(labels_np, preds_np, digits=4))

        cm = confusion_matrix(labels_np, preds_np)
        plt.figure(figsize=(10, 8))
        sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=dataset.classes, yticklabels=dataset.classes)
        plt.title(f"{split} Confusion Matrix")
        plt.xlabel("Predicted")
        plt.ylabel("True")
        plt.tight_layout()
        plt.show()

        labels_bin = label_binarize(labels_np, classes=list(range(NUM_CLASSES)))
        fpr, tpr, roc_auc = {}, {}, {}
        for i in range(NUM_CLASSES):
            fpr[i], tpr[i], _ = roc_curve(labels_bin[:, i], probs_np[:, i])
            roc_auc[i] = auc(fpr[i], tpr[i])

        plt.figure(figsize=(10, 8))
        for i in range(NUM_CLASSES):
            plt.plot(fpr[i], tpr[i], label=f"Class {i} (AUC={roc_auc[i]:.2f})")
        plt.plot([0, 1], [0, 1], 'k--')
        plt.title(f"{split} ROC Curve")
        plt.xlabel("False Positive Rate")
        plt.ylabel("True Positive Rate")
        plt.legend(loc="lower right")
        plt.tight_layout()
        plt.show()

    return avg_loss, acc

# --------------------- Metrics Plot --------------------- #
def plot_metrics():
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(train_loss_history, label="Train Loss")
    plt.plot(val_loss_history, label="Val Loss")
    plt.title("Loss per Epoch")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(train_acc_history, label="Train Acc")
    plt.plot(val_acc_history, label="Val Acc")
    plt.title("Accuracy per Epoch")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()

    plt.tight_layout()
    plt.show()

# --------------------- Main --------------------- #
if __name__ == "__main__":
    train()
    evaluate(test_loader, split="Test")
    plot_metrics()
# Out:
# /home/jupyter-228w1a4216/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/jupyter-228w1a4216/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /home/jupyter-228w1a4216/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# ✅ Best model saved (epoch 1) | Val Acc: 0.4100
# [Epoch 1] LR: 0.001000 | Train Loss: 1.8436 | Train Acc: 0.2895 | Val Loss: 1.5343 | Val Acc: 0.4100
# ✅ Best model saved (epoch 2) | Val Acc: 0.4267
# [Epoch 2] LR: 0.001000 | Train Loss: 1.5484 | Train Acc: 0.3862 | Val Loss: 1.4428 | Val Acc: 0.4267
# [Epoch 3] LR: 0.001000 | Train Loss: 1.4815 | Train Acc: 0.4183 | Val Loss: 1.4191 | Val Acc: 0.4256
# [Epoch 4] LR: 0.001000 | Train Loss: 1.4556 | Train Acc: 0.4267 | Val Loss: 1.4645 | Val Acc: 0.4033
# ✅ Best model saved (epoch 5) | Val Acc: 0.4333
# [Epoch 5] LR: 0.001000 | Train Loss: 1.4224 | Train Acc: 0.4324 | Val Loss: 1.3834 | Val Acc: 0.4333
# >>> 🔓 Unfreezing feature extractor
# ✅ Best model saved (epoch 6) | Val Acc: 0.5300
# [Epoch 6] LR: 0.001000 | Train Loss: 1.2883 | Train Acc: 0.4871 | Val Loss: 1.1811 | Val Acc: 0.5300
# ✅ Best model saved (epoch 7) | Val Acc: 0.5578
# [Epoch 7] LR: 0.001000 | Train Loss: 1.1557 | Train Acc: 0.5393 | Val Loss: 1.0806 | Val Acc: 0.5578
# ✅ Best model saved (epoch 8) | Val Acc: 0.6300
# [Epoch 8] LR: 0.001000 | Train Loss: 1.0417 | Train Acc: 0.5905 | Val Loss: 0.9463 | Val Acc: 0.6300
# ✅ Best model saved (epoch 9) | Val Acc: 0.6778
# [Epoch 9] LR: 0.001000 | Train Loss: 0.9390 | Train Acc: 0.6374 | Val Loss: 0.8314 | Val Acc: 0.6778
# ✅ Best model saved (epoch 10) | Val Acc: 0.7367
# [Epoch 10] LR: 0.001000 | Train Loss: 0.7988 | Train Acc: 0.7090 | Val Loss: 0.7013 | Val Acc: 0.7367
# ✅ Best model saved (epoch 11) | Val Acc: 0.7822
# [Epoch 11] LR: 0.001000 | Train Loss: 0.7167 | Train Acc: 0.7345 | Val Loss: 0.5912 | Val Acc: 0.7822
# ✅ Best model saved (epoch 12) | Val Acc: 0.7978
# [Epoch 12] LR: 0.001000 | Train Loss: 0.6438 | Train Acc: 0.7562 | Val Loss: 0.5587 | Val Acc: 0.7978
# ✅ Best model saved (epoch 13) | Val Acc: 0.8389
# [Epoch 13] LR: 0.001000 | Train Loss: 0.5925 | Train Acc: 0.7810 | Val Loss: 0.4642 | Val Acc: 0.8389
# [Epoch 14] LR: 0.001000 | Train Loss: 0.5723 | Train Acc: 0.7857 | Val Loss: 0.4605 | Val Acc: 0.8333
# [Epoch 15] LR: 0.001000 | Train Loss: 0.4879 | Train Acc: 0.8283 | Val Loss: 0.4497 | Val Acc: 0.8300
# ✅ Best model saved (epoch 16) | Val Acc: 0.8456
# [Epoch 16] LR: 0.001000 | Train Loss: 0.5022 | Train Acc: 0.8133 | Val Loss: 0.3991 | Val Acc: 0.8456
# ✅ Best model saved (epoch 17) | Val Acc: 0.8500
# [Epoch 17] LR: 0.001000 | Train Loss: 0.4636 | Train Acc: 0.8260 | Val Loss: 0.3895 | Val Acc: 0.8500
# [Epoch 18] LR: 0.001000 | Train Loss: 0.4401 | Train Acc: 0.8333 | Val Loss: 0.3788 | Val Acc: 0.8478
# ✅ Best model saved (epoch 19) | Val Acc: 0.8711
# [Epoch 19] LR: 0.001000 | Train Loss: 0.4234 | Train Acc: 0.8440 | Val Loss: 0.3462 | Val Acc: 0.8711
# [Epoch 20] LR: 0.001000 | Train Loss: 0.4258 | Train Acc: 0.8464 | Val Loss: 0.3461 | Val Acc: 0.8622
# [Epoch 21] LR: 0.001000 | Train Loss: 0.3917 | Train Acc: 0.8605 | Val Loss: 0.3238 | Val Acc: 0.8711
# [Epoch 22] LR: 0.001000 | Train Loss: 0.3872 | Train Acc: 0.8633 | Val Loss: 0.3515 | Val Acc: 0.8578
# [Epoch 23] LR: 0.000500 | Train Loss: 0.3753 | Train Acc: 0.8645 | Val Loss: 0.3769 | Val Acc: 0.8511
# [Epoch 24] LR: 0.000500 | Train Loss: 0.3443 | Train Acc: 0.8714 | Val Loss: 0.3429 | Val Acc: 0.8578
# [Epoch 25] LR: 0.000500 | Train Loss: 0.3623 | Train Acc: 0.8710 | Val Loss: 0.3356 | Val Acc: 0.8667
# ✅ Best model saved (epoch 26) | Val Acc: 0.8800
# [Epoch 26] LR: 0.000500 | Train Loss: 0.3355 | Train Acc: 0.8821 | Val Loss: 0.3139 | Val Acc: 0.8800
# [Epoch 27] LR: 0.000500 | Train Loss: 0.3443 | Train Acc: 0.8869 | Val Loss: 0.3138 | Val Acc: 0.8700
# [Epoch 28] LR: 0.000500 | Train Loss: 0.3375 | Train Acc: 0.8810 | Val Loss: 0.3186 | Val Acc: 0.8633
# [Epoch 29] LR: 0.000500 | Train Loss: 0.3138 | Train Acc: 0.8867 | Val Loss: 0.3308 | Val Acc: 0.8700
# [Epoch 30] LR: 0.000250 | Train Loss: 0.3100 | Train Acc: 0.8902 | Val Loss: 0.3247 | Val Acc: 0.8800
# [Epoch 31] LR: 0.000250 | Train Loss: 0.2994 | Train Acc: 0.8912 | Val Loss: 0.3473 | Val Acc: 0.8656
# [Epoch 32] LR: 0.000250 | Train Loss: 0.2858 | Train Acc: 0.8993 | Val Loss: 0.3282 | Val Acc: 0.8689
# [Epoch 33] LR: 0.000250 | Train Loss: 0.2884 | Train Acc: 0.8988 | Val Loss: 0.3497 | Val Acc: 0.8667
# [Epoch 34] LR: 0.000125 | Train Loss: 0.2910 | Train Acc: 0.8979 | Val Loss: 0.3380 | Val Acc: 0.8711
# [Epoch 35] LR: 0.000125 | Train Loss: 0.2841 | Train Acc: 0.8993 | Val Loss: 0.3210 | Val Acc: 0.8756
# [Epoch 36] LR: 0.000125 | Train Loss: 0.2595 | Train Acc: 0.9067 | Val Loss: 0.3380 | Val Acc: 0.8633
# [Epoch 37] LR: 0.000125 | Train Loss: 0.2623 | Train Acc: 0.9074 | Val Loss: 0.3336 | Val Acc: 0.8611
# [Epoch 38] LR: 0.000063 | Train Loss: 0.2606 | Train Acc: 0.9117 | Val Loss: 0.3179 | Val Acc: 0.8733
# [Epoch 39] LR: 0.000063 | Train Loss: 0.2544 | Train Acc: 0.9081 | Val Loss: 0.3277 | Val Acc: 0.8667
# [Epoch 40] LR: 0.000063 | Train Loss: 0.2747 | Train Acc: 0.9024 | Val Loss: 0.3213 | Val Acc: 0.8756
# ✅ Best model saved (epoch 41) | Val Acc: 0.8822
# [Epoch 41] LR: 0.000063 | Train Loss: 0.2701 | Train Acc: 0.9074 | Val Loss: 0.3198 | Val Acc: 0.8822
# [Epoch 42] LR: 0.000063 | Train Loss: 0.2708 | Train Acc: 0.9017 | Val Loss: 0.3241 | Val Acc: 0.8722
# [Epoch 43] LR: 0.000063 | Train Loss: 0.2585 | Train Acc: 0.9079 | Val Loss: 0.3218 | Val Acc: 0.8822
# [Epoch 44] LR: 0.000063 | Train Loss: 0.2625 | Train Acc: 0.9067 | Val Loss: 0.3276 | Val Acc: 0.8767
# [Epoch 45] LR: 0.000031 | Train Loss: 0.2686 | Train Acc: 0.9060 | Val Loss: 0.3349 | Val Acc: 0.8722
# [Epoch 46] LR: 0.000031 | Train Loss: 0.2720 | Train Acc: 0.9029 | Val Loss: 0.3396 | Val Acc: 0.8656
# [Epoch 47] LR: 0.000031 | Train Loss: 0.2668 | Train Acc: 0.9052 | Val Loss: 0.3324 | Val Acc: 0.8733
# [Epoch 48] LR: 0.000031 | Train Loss: 0.2724 | Train Acc: 0.9043 | Val Loss: 0.3446 | Val Acc: 0.8667
# [Epoch 49] LR: 0.000016 | Train Loss: 0.2372 | Train Acc: 0.9164 | Val Loss: 0.3160 | Val Acc: 0.8778
# [Epoch 50] LR: 0.000016 | Train Loss: 0.2552 | Train Acc: 0.9102 | Val Loss: 0.3242 | Val Acc: 0.8733
# [Epoch 51] LR: 0.000016 | Train Loss: 0.2680 | Train Acc: 0.9057 | Val Loss: 0.3277 | Val Acc: 0.8722
# [Epoch 52] LR: 0.000016 | Train Loss: 0.2328 | Train Acc: 0.9181 | Val Loss: 0.3445 | Val Acc: 0.8744
# [Epoch 53] LR: 0.000008 | Train Loss: 0.2408 | Train Acc: 0.9098 | Val Loss: 0.3339 | Val Acc: 0.8756
# [Epoch 54] LR: 0.000008 | Train Loss: 0.2429 | Train Acc: 0.9152 | Val Loss: 0.3476 | Val Acc: 0.8644
# [Epoch 55] LR: 0.000008 | Train Loss: 0.2577 | Train Acc: 0.9086 | Val Loss: 0.3476 | Val Acc: 0.8756
# [Epoch 56] LR: 0.000008 | Train Loss: 0.2424 | Train Acc: 0.9157 | Val Loss: 0.3389 | Val Acc: 0.8689
# [Epoch 57] LR: 0.000004 | Train Loss: 0.2512 | Train Acc: 0.9112 | Val Loss: 0.3364 | Val Acc: 0.8700
# [Epoch 58] LR: 0.000004 | Train Loss: 0.2428 | Train Acc: 0.9138 | Val Loss: 0.3265 | Val Acc: 0.8722
# [Epoch 59] LR: 0.000004 | Train Loss: 0.2453 | Train Acc: 0.9102 | Val Loss: 0.3228 | Val Acc: 0.8789
# [Epoch 60] LR: 0.000004 | Train Loss: 0.2499 | Train Acc: 0.9114 | Val Loss: 0.3273 | Val Acc: 0.8733
# [Epoch 61] LR: 0.000002 | Train Loss: 0.2408 | Train Acc: 0.9110 | Val Loss: 0.3353 | Val Acc: 0.8733
# [Epoch 62] LR: 0.000002 | Train Loss: 0.2482 | Train Acc: 0.9140 | Val Loss: 0.3487 | Val Acc: 0.8689
# [Epoch 63] LR: 0.000002 | Train Loss: 0.2481 | Train Acc: 0.9131 | Val Loss: 0.3355 | Val Acc: 0.8700
# [Epoch 64] LR: 0.000002 | Train Loss: 0.2455 | Train Acc: 0.9126 | Val Loss: 0.3284 | Val Acc: 0.8711
# [Epoch 65] LR: 0.000001 | Train Loss: 0.2731 | Train Acc: 0.9062 | Val Loss: 0.3319 | Val Acc: 0.8722
# [Epoch 66] LR: 0.000001 | Train Loss: 0.2356 | Train Acc: 0.9195 | Val Loss: 0.3312 | Val Acc: 0.8789
# [Epoch 67] LR: 0.000001 | Train Loss: 0.2578 | Train Acc: 0.9114 | Val Loss: 0.3364 | Val Acc: 0.8756
# [Epoch 68] LR: 0.000001 | Train Loss: 0.2377 | Train Acc: 0.9183 | Val Loss: 0.3405 | Val Acc: 0.8689
# [Epoch 69] LR: 0.000000 | Train Loss: 0.2373 | Train Acc: 0.9217 | Val Loss: 0.3386 | Val Acc: 0.8678
# [Epoch 70] LR: 0.000000 | Train Loss: 0.2522 | Train Acc: 0.9107 | Val Loss: 0.3243 | Val Acc: 0.8767
# [Epoch 71] LR: 0.000000 | Train Loss: 0.2577 | Train Acc: 0.9019 | Val Loss: 0.3177 | Val Acc: 0.8733
# [Epoch 72] LR: 0.000000 | Train Loss: 0.2579 | Train Acc: 0.9081 | Val Loss: 0.3266 | Val Acc: 0.8789
# [Epoch 73] LR: 0.000000 | Train Loss: 0.2438 | Train Acc: 0.9117 | Val Loss: 0.3328 | Val Acc: 0.8800
# [Epoch 74] LR: 0.000000 | Train Loss: 0.2461 | Train Acc: 0.9083 | Val Loss: 0.3356 | Val Acc: 0.8733
# [Epoch 75] LR: 0.000000 | Train Loss: 0.2422 | Train Acc: 0.9136 | Val Loss: 0.3241 | Val Acc: 0.8722
# [Epoch 76] LR: 0.000000 | Train Loss: 0.2476 | Train Acc: 0.9145 | Val Loss: 0.3257 | Val Acc: 0.8711
# [Epoch 77] LR: 0.000000 | Train Loss: 0.2651 | Train Acc: 0.9083 | Val Loss: 0.3252 | Val Acc: 0.8689
# [Epoch 78] LR: 0.000000 | Train Loss: 0.2519 | Train Acc: 0.9114 | Val Loss: 0.3452 | Val Acc: 0.8733
# [Epoch 79] LR: 0.000000 | Train Loss: 0.2506 | Train Acc: 0.9110 | Val Loss: 0.3332 | Val Acc: 0.8700
# [Epoch 80] LR: 0.000000 | Train Loss: 0.2399 | Train Acc: 0.9171 | Val Loss: 0.3130 | Val Acc: 0.8744
# [Epoch 81] LR: 0.000000 | Train Loss: 0.2445 | Train Acc: 0.9129 | Val Loss: 0.3209 | Val Acc: 0.8800
# [Epoch 82] LR: 0.000000 | Train Loss: 0.2285 | Train Acc: 0.9174 | Val Loss: 0.3282 | Val Acc: 0.8722
# [Epoch 83] LR: 0.000000 | Train Loss: 0.2456 | Train Acc: 0.9081 | Val Loss: 0.3307 | Val Acc: 0.8733
# [Epoch 84] LR: 0.000000 | Train Loss: 0.2332 | Train Acc: 0.9200 | Val Loss: 0.3308 | Val Acc: 0.8678
# [Epoch 85] LR: 0.000000 | Train Loss: 0.2549 | Train Acc: 0.9110 | Val Loss: 0.3478 | Val Acc: 0.8633
# [Epoch 86] LR: 0.000000 | Train Loss: 0.2612 | Train Acc: 0.9055 | Val Loss: 0.3610 | Val Acc: 0.8667
# [Epoch 87] LR: 0.000000 | Train Loss: 0.2677 | Train Acc: 0.9093 | Val Loss: 0.3498 | Val Acc: 0.8633
# [Epoch 88] LR: 0.000000 | Train Loss: 0.2754 | Train Acc: 0.9036 | Val Loss: 0.3434 | Val Acc: 0.8667
# [Epoch 89] LR: 0.000000 | Train Loss: 0.2374 | Train Acc: 0.9183 | Val Loss: 0.3268 | Val Acc: 0.8767
# [Epoch 90] LR: 0.000000 | Train Loss: 0.2558 | Train Acc: 0.9088 | Val Loss: 0.3336 | Val Acc: 0.8656
# [Epoch 91] LR: 0.000000 | Train Loss: 0.2384 | Train Acc: 0.9164 | Val Loss: 0.3236 | Val Acc: 0.8767
# [Epoch 92] LR: 0.000000 | Train Loss: 0.2448 | Train Acc: 0.9121 | Val Loss: 0.3440 | Val Acc: 0.8678
# [Epoch 93] LR: 0.000000 | Train Loss: 0.2213 | Train Acc: 0.9229 | Val Loss: 0.3276 | Val Acc: 0.8711
# [Epoch 94] LR: 0.000000 | Train Loss: 0.2565 | Train Acc: 0.9083 | Val Loss: 0.3371 | Val Acc: 0.8711
# [Epoch 95] LR: 0.000000 | Train Loss: 0.2697 | Train Acc: 0.9060 | Val Loss: 0.3367 | Val Acc: 0.8689
# [Epoch 96] LR: 0.000000 | Train Loss: 0.2515 | Train Acc: 0.9126 | Val Loss: 0.3354 | Val Acc: 0.8733
# [Epoch 97] LR: 0.000000 | Train Loss: 0.2467 | Train Acc: 0.9133 | Val Loss: 0.3399 | Val Acc: 0.8722
# [Epoch 98] LR: 0.000000 | Train Loss: 0.2338 | Train Acc: 0.9174 | Val Loss: 0.3194 | Val Acc: 0.8767
# [Epoch 99] LR: 0.000000 | Train Loss: 0.2489 | Train Acc: 0.9050 | Val Loss: 0.3172 | Val Acc: 0.8767
# [Epoch 100] LR: 0.000000 | Train Loss: 0.2563 | Train Acc: 0.9110 | Val Loss: 0.3450 | Val Acc: 0.8644
#
# [Test Set]
# Loss: 0.3924 | Accuracy: 0.8557
#               precision    recall  f1-score   support
#
#            0     0.8778    0.9294    0.9029        85
#            1     0.8803    0.8224    0.8503       152
#            2     0.8947    0.8019    0.8458       106
#            3     0.8099    0.8596    0.8340       114
#            4     0.8916    0.7551    0.8177        98
#            5     0.8413    0.9550    0.8945       111
#            6     0.8540    0.9141    0.8830       128
#            7     0.8131    0.8131    0.8131       107
#
#     accuracy                         0.8557       901
#    macro avg     0.8578    0.8563    0.8552       901
# weighted avg     0.8576    0.8557    0.8548       901
